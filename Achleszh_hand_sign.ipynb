# %%
import numpy as np
import pandas as pd
import cv2
import mediapipe as mp
from sklearn.ensemble import RandomForestClassifier
import optuna
from optuna.samplers import GridSampler
from sklearn.metrics import accuracy_score,log_loss
from sklearn.model_selection import train_test_split,cross_validate

import time
import pyttsx3


import warnings
warnings.filterwarnings("ignore")

# %%
hands = mp.solutions.hands
draw = mp.solutions.drawing_utils
mp_styles = mp.solutions.drawing_styles

# %%
sign_df=pd.read_csv(r"hand_sign_dataset.csv")

# %%
fv=sign_df.iloc[:,:-1]
cv=sign_df.iloc[:,-1]

# %%
final_data = []
for d in fv.values:
    md = d.reshape(42,3)
    center = md-md[0]
    distance = np.linalg.norm(md[12]-md[0])
    fpd = center/distance
    final_data.append(fpd.flatten())

fv_final=pd.DataFrame(final_data)

# %%
X_train,X_test,y_train,y_test = train_test_split(fv_final,cv,test_size=0.2,stratify=cv,random_state=40)

# %%
def objective(trial):
  # define hyperparameter
    n_estimators=trial.suggest_int('n_estimators',3,40)
    max_depth=trial.suggest_int('max_depth',3,30)
    min_samples_split=trial.suggest_int('min_samples_split',2,15)
    min_samples_leaf=trial.suggest_int('min_samples_leaf',1,20)
    
    rf=RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf)


  #training by using k-fold acc
    values=cross_validate(rf,X_train,y_train,cv=3,scoring='accuracy',return_train_score=True)
    cv_acc=values['test_score'].mean()
    train_acc=values['train_score'].mean()
    
    #return additional parameter
    trial.set_user_attr('train_acc',train_acc)
    
    return cv_acc

# %%
study=optuna.create_study(direction="maximize")
# Out:
# [I 2025-08-02 17:43:27,933] A new study created in memory with name: no-name-d3ef343a-2e89-474d-aaf3-3587a6921040

# %%
study.optimize(objective,n_trials=100)
# Out:
# [I 2025-08-02 17:43:35,419] Trial 0 finished with value: 0.9998611111111111 and parameters: {'n_estimators': 28, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 9}. Best is trial 0 with value: 0.9998611111111111.
# [I 2025-08-02 17:43:43,994] Trial 1 finished with value: 0.9998611111111111 and parameters: {'n_estimators': 36, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 7}. Best is trial 0 with value: 0.9998611111111111.
# [I 2025-08-02 17:43:47,658] Trial 2 finished with value: 0.9998611111111111 and parameters: {'n_estimators': 14, 'max_depth': 20, 'min_samples_split': 14, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.9998611111111111.
# [I 2025-08-02 17:43:54,283] Trial 3 finished with value: 0.9995833333333334 and parameters: {'n_estimators': 33, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 15}. Best is trial 0 with value: 0.9998611111111111.
# [I 2025-08-02 17:43:59,523] Trial 4 finished with value: 0.9998611111111111 and parameters: {'n_estimators': 23, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.9998611111111111.
# [I 2025-08-02 17:44:08,400] Trial 5 finished with value: 0.9998611111111111 and parameters: {'n_estimators': 37, 'max_depth': 23, 'min_samples_split': 5, 'min_samples_leaf': 8}. Best is trial 0 with value: 0.9998611111111111.
# [I 2025-08-02 17:44:17,202] Trial 6 finished with value: 1.0 and parameters: {'n_estimators': 36, 'max_depth': 22, 'min_samples_split': 3, 'min_samples_leaf': 6}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:44:23,596] Trial 7 finished with value: 0.9997222222222222 and parameters: {'n_estimators': 26, 'max_depth': 29, 'min_samples_split': 13, 'min_samples_leaf': 18}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:44:28,239] Trial 8 finished with value: 0.9998611111111111 and parameters: {'n_estimators': 20, 'max_depth': 12, 'min_samples_split': 15, 'min_samples_leaf': 1}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:44:36,980] Trial 9 finished with value: 1.0 and parameters: {'n_estimators': 37, 'max_depth': 29, 'min_samples_split': 4, 'min_samples_leaf': 8}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:44:38,508] Trial 10 finished with value: 0.9990277777777777 and parameters: {'n_estimators': 6, 'max_depth': 23, 'min_samples_split': 9, 'min_samples_leaf': 14}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:44:48,373] Trial 11 finished with value: 1.0 and parameters: {'n_estimators': 39, 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 6}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:44:56,195] Trial 12 finished with value: 0.9997222222222222 and parameters: {'n_estimators': 32, 'max_depth': 26, 'min_samples_split': 8, 'min_samples_leaf': 13}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:45:05,394] Trial 13 finished with value: 0.9998611111111111 and parameters: {'n_estimators': 40, 'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 10}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:45:13,152] Trial 14 finished with value: 1.0 and parameters: {'n_estimators': 30, 'max_depth': 26, 'min_samples_split': 4, 'min_samples_leaf': 5}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:45:16,961] Trial 15 finished with value: 0.9995833333333333 and parameters: {'n_estimators': 15, 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 12}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:45:25,037] Trial 16 finished with value: 0.9998611111111111 and parameters: {'n_estimators': 33, 'max_depth': 27, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:45:30,965] Trial 17 finished with value: 0.9998611111111111 and parameters: {'n_estimators': 24, 'max_depth': 23, 'min_samples_split': 6, 'min_samples_leaf': 10}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:45:33,555] Trial 18 finished with value: 0.9172222222222222 and parameters: {'n_estimators': 19, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 20}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:45:35,041] Trial 19 finished with value: 0.9994444444444444 and parameters: {'n_estimators': 6, 'max_depth': 18, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:45:43,483] Trial 20 finished with value: 0.9998611111111111 and parameters: {'n_estimators': 35, 'max_depth': 25, 'min_samples_split': 6, 'min_samples_leaf': 7}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:45:53,174] Trial 21 finished with value: 0.9997222222222222 and parameters: {'n_estimators': 40, 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 6}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:46:02,339] Trial 22 finished with value: 1.0 and parameters: {'n_estimators': 38, 'max_depth': 29, 'min_samples_split': 3, 'min_samples_leaf': 5}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:46:09,177] Trial 23 finished with value: 0.9997222222222222 and parameters: {'n_estimators': 29, 'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 8}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:46:17,718] Trial 24 finished with value: 1.0 and parameters: {'n_estimators': 35, 'max_depth': 27, 'min_samples_split': 5, 'min_samples_leaf': 11}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:46:27,465] Trial 25 finished with value: 0.9998611111111111 and parameters: {'n_estimators': 40, 'max_depth': 24, 'min_samples_split': 3, 'min_samples_leaf': 6}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:46:35,319] Trial 26 finished with value: 0.9998611111111111 and parameters: {'n_estimators': 31, 'max_depth': 28, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:46:41,920] Trial 27 finished with value: 0.9995833333333334 and parameters: {'n_estimators': 27, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 9}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:46:50,622] Trial 28 finished with value: 0.9998611111111111 and parameters: {'n_estimators': 37, 'max_depth': 21, 'min_samples_split': 2, 'min_samples_leaf': 7}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17
 'max_depth': 29, 'min_samples_split': 3, 'min_samples_leaf': 8}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:55:51,993] Trial 95 finished with value: 0.9998611111111111 and parameters: {'n_estimators': 40, 'max_depth': 23, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:55:59,224] Trial 96 finished with value: 1.0 and parameters: {'n_estimators': 31, 'max_depth': 27, 'min_samples_split': 3, 'min_samples_leaf': 6}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:56:06,299] Trial 97 finished with value: 0.9998611111111111 and parameters: {'n_estimators': 34, 'max_depth': 26, 'min_samples_split': 2, 'min_samples_leaf': 3}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:56:09,269] Trial 98 finished with value: 0.9993055555555556 and parameters: {'n_estimators': 12, 'max_depth': 30, 'min_samples_split': 4, 'min_samples_leaf': 6}. Best is trial 6 with value: 1.0.
# [I 2025-08-02 17:56:17,340] Trial 99 finished with value: 0.9998611111111111 and parameters: {'n_estimators': 37, 'max_depth': 28, 'min_samples_split': 5, 'min_samples_leaf': 10}. Best is trial 6 with value: 1.0.

# %%
study.best_params
# Out:
# {'n_estimators': 36,
#  'max_depth': 22,
#  'min_samples_split': 3,
#  'min_samples_leaf': 6}

# %%
rf = RandomForestClassifier(n_estimators=36,
                                    max_depth=2,
                                    min_samples_split=3,
                                    min_samples_leaf=6)

rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=2, min_samples_leaf=6, min_samples_split=3,
#                        n_estimators=36)

# %%
y_pred=rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6294444444444445

# %%
# import pickle
# with open('sign_model3_new.pkl', 'wb') as f:
#     rf=pickle.dump(rf,f)

# %%
import pickle
with open('sign_model3_new.pkl', 'rb') as f:
    rf=pickle.load(f)

# %%
def speak(text):
    engine = pyttsx3.init()
    engine.say(text)
    engine.runAndWait()
    engine.stop()

# %%
fm_model = hands.Hands(static_image_mode=True,
                       min_detection_confidence=0.9,
                       min_tracking_confidence=0.9,
                       max_num_hands=2)

vid = cv2.VideoCapture(1)
pred = None
sentence = ""
last_update_time = time.time()
delay_between_predictions = 1

status_msg = ""
start_prediction = False

while True:
    b, f = vid.read()
    # f = cv2.flip(f, 1)
    if not b:
        break

    rgb = cv2.cvtColor(f, cv2.COLOR_BGR2RGB)
    result = fm_model.process(rgb)

    if result.multi_hand_landmarks:
        # Draw landmarks for all detected hands
        for hand_landmarks in result.multi_hand_landmarks:
            mp.solutions.drawing_utils.draw_landmarks(
                image=f,
                landmark_list=hand_landmarks,
                connections=hands.HAND_CONNECTIONS,
                landmark_drawing_spec=mp_styles.get_default_hand_landmarks_style(),
                connection_drawing_spec=mp_styles.get_default_hand_connections_style()
            )

        all_hands = []
        for hand_landmarks in result.multi_hand_landmarks:
            hand = []
            for lm in hand_landmarks.landmark:
                hand.extend([lm.x, lm.y, lm.z])
            all_hands.append(hand)

        if len(all_hands) == 2:  # Ensure 2 hands detected
            combined_hand = all_hands[0] + all_hands[1]  # concatenate both hands
            d = np.array(combined_hand)
            md = d.reshape(42, 3)  # 42 landmarks (2x21) with 3 coords each
            center = md - md[0]
            distance = np.linalg.norm(md[12] - md[0])
            if distance != 0:
                fpd = center / distance
                fv_final = pd.DataFrame([fpd.flatten()])  # single row for prediction

                prediction = rf.predict(fv_final)
                pred = prediction[0]

                current_time = time.time()

                if pred == "START":
                    start_prediction = True
                    status_msg = "Started collecting data"

                elif pred == "STOP":
                    start_prediction = False
                    status_msg = "Stopped collecting data"
                    speak(sentence)

                elif start_prediction and (current_time - last_update_time > delay_between_predictions):
                    if pred == "SPACE":
                        sentence += " "
                    elif pred == "FULLSTOP":
                        sentence += "."
                    elif pred == "BACKSPACE":
                        sentence = sentence[:-1]
                    else:
                        sentence += pred

                    last_update_time = current_time
        else:
            pred = None  # Not exactly 2 hands detected, skip prediction

    else:
        pred = None

    cv2.putText(f, f"Sentence: {sentence}", (30, 70),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 5)

    if status_msg:
        cv2.putText(f, status_msg, (30, 120),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 3)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

    cv2.imshow("frame", f)

vid.release()
cv2.destroyAllWindows()
